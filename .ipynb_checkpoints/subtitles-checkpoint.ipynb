# %%
srt_file = "H:\\האחסון שלי\\קבצים ציבוריים\\Ivrit.AI\\שיעורים מתומללים SRT\\הרב יוסף צבי בן פורת\\ספירת העומר על מה ולמה. תשפד. 91540\\תשפ_ד. ספירת העומר על מה ולמה_. 91540.srt"

# %%
import pysrt

subs = pysrt.open(srt_file)

for sub in subs:
    
    print(f'Index: {sub.index}')
    print(f'Start: {sub.start} End: {sub.end}')
    print(sub.text)
    print()
# Out:
# Index: 1
# Start: 00:00:01,000 End: 00:00:03,000
# אנחנו נמצאים עכשיו במסע
#
# Index: 2
# Start: 00:00:07,000 End: 00:00:09,000
# לכיוון חג השבועות
#
# Index: 3
# Start: 00:00:13,000 End: 00:00:15,000
# אבני הדרך במסע הזה הם
#
# Index: 4
# Start: 00:00:16,000 End: 00:00:18,000
# גימי ספירת האומר
#
# Index: 5
# Start: 00:00:21,000 End: 00:00:23,000
# ואני שואל את השאלה
#
# Index: 6
# Start: 00:00:24,000 End: 00:00:26,000
# מה ההבנה שלנו
#
# Index: 7
# Start: 00:00:27,000 End: 00:00:29,000
# בעניין של ספירת האומר
#
# Index: 8
# Start: 00:00:31,000 End: 00:00:33,000
# ותעמי המצוות באמת אין להסיג
#
# Index: 9
# Start: 00:00:35,000 End: 00:00:37,000
# הגרע כותב בפירושו לבשלה
#
# Index: 10
# Start: 00:00:39,000 End: 00:00:41,000
# שאפילו משה רבנו לא ידע תעמי המצוות
#
# Index: 11
# Start: 00:00:43,000 End: 00:00:45,000
# לא ידע איש ערכה
#
# Index: 12
# Start: 00:00:46,000 End: 00:00:47,000
# זה משה
#
# Index: 13
# Start: 00:00:48,000 End: 00:00:49,000
# שנאמר והאיש משה
#
# Index: 14
# ...

# %%
r = subs.slice(ends_after={'minutes':10})

r[0].text
# Out:
# 'כי הם חיינו'
